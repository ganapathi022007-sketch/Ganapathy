# %%
a=5
b=5.2
c='A'
d="name"
e= True

# %%
print ("integer:", a);
print ("float:",b);
print ("charather:",c);
print ("string:",d);
print ("boolean:",e);
# Out:
# integer: 5
# float: 5.2
# charather: A
# string: name
# boolean: True

# %%
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>

# %%
a=15
b=10
add=a+b
print("add",add)
sub=a-b
print("sub",sub)
mul=a*b
print("mul",mul)
div=a/b
print("div",div)
mod=a%b
print("mod",mod)
flo_div=a//b
print("div",flo_div)
# Out:
# add 25
# sub 5
# mul 150
# div 1.5
# mod 5
# div 1

# %%
print(a>b)
print(a=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# True
# False
# False
# False
# True

# %%
c=True
d= False

print(c and d)
print(c or d)
print(not a)
# Out:
# False
# True
# False
